# %%
import tensorflow as tf

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# X and Y data
x_train = [1,2,3]
y_train = [1,2,3]

# %%
# 예측치가 결과값이랑 같게끔 하려면 [W = 1 , b = 0]에 가깝게

W = tf.Variable(tf.random_normal([1]), name = 'weight')
b = tf.Variable(tf.random_normal([1]), name = 'bias')

# %% [markdown]
# ![%EC%BA%A1%EC%B2%98.PNG](attachment:%EC%BA%A1%EC%B2%98.PNG)

# %%
hypothesis = x_train * W + b

# %% [markdown]
# ![%EC%BA%A1%EC%B2%982.PNG](attachment:%EC%BA%A1%EC%B2%982.PNG)

# %%
cost = tf.reduce_mean(tf.square(hypothesis - y_train))

# %% [markdown]
# ![%EC%BA%A1%EC%B2%983.PNG](attachment:%EC%BA%A1%EC%B2%983.PNG)

# %%
optimizer = tf.train.GradientDescentOptimizer(learning_rate = 0.01)
train = optimizer.minimize(cost)

# %%
sess = tf.Session()
sess.run(tf.global_variables_initializer())

# %%
for step in range(2001):
    sess.run(train)
    if step % 20 == 0:
        print(step, sess.run(cost), sess.run(W), sess.run(b))
# Out:
# 0 4.537122 [0.20714387] [-0.4435834]
# 20 0.0419507 [0.95447814] [-0.11037426]
# 40 0.001119521 [1.0242302] [-0.07544414]
# 60 0.0006814765 [1.0295296] [-0.06906647]
# 80 0.0006158888 [1.0287548] [-0.06555095]
# 100 0.000559331 [1.0274616] [-0.06244459]
# 120 0.0005079936 [1.0261767] [-0.05950742]
# 140 0.00046136815 [1.024947] [-0.05671059]
# 160 0.00041902112 [1.0237746] [-0.0540454]
# 180 0.00038056241 [1.0226574] [-0.05150548]
# 200 0.00034563456 [1.0215926] [-0.04908495]
# 220 0.00031391275 [1.0205781] [-0.04677835]
# 240 0.00028510447 [1.019611] [-0.04458014]
# 260 0.00025893206 [1.018689] [-0.04248495]
# 280 0.00023516582 [1.0178107] [-0.04048824]
# 300 0.00021358154 [1.0169737] [-0.03858538]
# 320 0.00019397843 [1.016176] [-0.03677199]
# 340 0.00017617592 [1.0154158] [-0.03504381]
# 360 0.00016000298 [1.0146914] [-0.03339687]
# 380 0.00014531733 [1.0140009] [-0.03182733]
# 400 0.0001319795 [1.0133429] [-0.03033154]
# 420 0.00011986663 [1.0127158] [-0.02890608]
# 440 0.00010886427 [1.0121181] [-0.02754757]
# 460 9.887144e-05 [1.0115488] [-0.02625288]
# 480 8.979783e-05 [1.011006] [-0.02501913]
# 500 8.1556085e-05 [1.0104887] [-0.02384336]
# 520 7.407039e-05 [1.0099958] [-0.02272281]
# 540 6.727156e-05 [1.0095259] [-0.02165487]
# 560 6.109683e-05 [1.0090783] [-0.02063712]
# 580 5.548853e-05 [1.0086516] [-0.01966722]
# 600 5.0395163e-05 [1.008245] [-0.01874294]
# 620 4.577028e-05 [1.0078576] [-0.01786208]
# 640 4.1570183e-05 [1.0074884] [-0.01702266]
# 660 3.775483e-05 [1.0071365] [-0.01622271]
# 680 3.428895e-05 [1.006801] [-0.01546031]
# 700 3.1141793e-05 [1.0064814] [-0.01473375]
# 720 2.8282915e-05 [1.0061768] [-0.01404133]
# 740 2.568758e-05 [1.0058866] [-0.01338145]
# 760 2.3329841e-05 [1.0056099] [-0.01275258]
# 780 2.1188522e-05 [1.0053463] [-0.01215327]
# 800 1.9244066e-05 [1.005095] [-0.01158213]
# 820 1.7477212e-05 [1.0048555] [-0.01103778]
# 840 1.5873935e-05 [1.0046273] [-0.01051906]
# 860 1.4416749e-05 [1.0044099] [-0.01002472]
# 880 1.3093219e-05 [1.0042027] [-0.00955363]
# 900 1.1891476e-05 [1.0040052] [-0.00910464]
# 920 1.0800101e-05 [1.003817] [-0.00867677]
# 940 9.808978e-06 [1.0036376] [-0.00826904]
# 960 8.90913e-06 [1.0034667] [-0.00788047]
# 980 8.091363e-06 [1.0033038] [-0.00751016]
# 1000 7.3482456e-06 [1.0031484] [-0.00715723]
# 1020 6.6742627e-06 [1.0030005] [-0.00682089]
# 1040 6.0615876e-06 [1.0028596] [-0.00650037]
# 1060 5.505702e-06 [1.0027252] [-0.0061949]
# 1080 5.000354e-06 [1.0025971] [-0.00590382]
# 1100 4.5411375e-06 [1.0024751] [-0.00562641]
# 1120 4.124447e-06 [1.0023588] [-0.00536202]
# 1140 3.7462353e-06 [1.0022479] [-0.00511006]
# 1160 3.4021348e-06 [1.0021423] [-0.00486995]
# 1180 3.0899903e-06 [1.0020417] [-0.0046411]
# 1200 2.806358e-06 [1.0019457] [-0.00442303]
# 1220 2.5487695e-06 [1.0018543] [-0.00421521]
# 1240 2.3150824e-06 [1.0017672] [-0.00401716]
# 1260 2.102864e-06 [1.0016843] [-0.0038284]
# 1280 1.9096624e-06 [1.001605] [-0.00364852]
# 1300 1.7344561e-06 [1.0015297] [-0.00347712]
# 1320 1.5752962e-06 [1.0014577] [-0.00331376]
# 1340 1.4306619e-06 [1.0013894] [-0.00315806]
# 1360 1.2993933e-06 [1.001324] [-0.00300971]
# 1380 1.1803137e-06 [1.0012618] [-0.00286834]
# 1400 1.07212e-06 [1.0012027] [-0.00273365]
# 1420 9.738665e-07 [1.0011463] [-0.00260531]
# 1440 8.8450474e-07 [1.0010924] [-0.00248298]
# 1460 8.033794e-07 [1.0010412] [-0.00236636]
# 1480 7.297144e-07 [1.0009923] [-0.00225523]
# 1500 6.628189e-07 [1.0009457] [-0.00214932]
# 1520 6.0197465e-07 [1.0009013] [-0.0020484]
# 1540 5.468484e-07 [1.0008589] [-0.00195225]
# 1560 4.966316e-07 [1.0008185] [-0.00186062]
# 1580 4.5116917e-07 [1.0007802] [-0.00177333]
# 1600 4.0974547e-07 [1.0007437] [-0.00169008]
# 1620 3.7226445e-07 [1.0007087] [-0.00161073]
# 1640 3.3813117e-07 [1.0006753] [-0.00153519]
# 1660 3.0717192e-07 [1.000644] [-0.00146316]
# 1680 2.7895615e-07 [1.0006136] [-0.00139449]
# 1700 2.5344985e-07 [1.000585] [-0.00132918]
# 1720 2.3030071e-07 [1.0005575] [-0.00126678]
# 1740 2.0917606e-07 [1.0005313] [-0.0012075]
# 1760 1.9003603e-07 [1.0005065] [-0.0011508]
# 1780 1.7266728e-07 [1.0004827] [-0.00109695]
# 1800 1.567616e-07 [1.00046] [-0.00104542]
# 1820 1.4241823e-07 [1.0004386] [-0.0009965]
# 1840 1.2942023e-07 [1.0004178] [-0.00094967]
# 1860 1.1760515e-07 [1.0003986] [-0.00090525]
# 1880 1.06828715e-07 [1.0003796] [-0.00086291]
# 1900 9.707721e-08 [1.000362] [-0.00082237]
# 1920 8.821553e-08 [1.0003452] [-0.00078398]
# 1940 8.0098026e-08 [1.0003285] [-0.00074725]
# 1960 7.278363e-08 [1.0003134] [-0.00071215]
# 1980 6.6167324e-08 [1.0002991] [-0.00067894]
# 2000 6.0113756e-08 [1.0002848] [-0.00064727]

# %%
# Out:
#   File "<ipython-input-17-c39bdfeff5ed>", line 1
#     print(sess.run(hypothesis)
#                               ^
# SyntaxError: unexpected EOF while parsing
